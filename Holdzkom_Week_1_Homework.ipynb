# %% [markdown]
# <a href="https://colab.research.google.com/github/lizholdzkom/AdvancedPython/blob/main/Holdzkom_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://lis-info671-fall2023.github.io/Group4-arizona-postcard/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Fort Defiance - Two brick buildings ",
#   "creator": "Unknown",
#   "date": "1896",
#   "description": "Two brick buildings in Fort Defiance, Arizona. Today, the site of Fort Defiance is populated by buildings dating from the 1930s to the present day used by various governmental agencies including the Bureau of Indian Affairs, Indian Health Service, and the Navajo Nation.",
#   "subject": "Fort Defiance, Arizona;Brick Buildings;Navajo Nation",
#   "location": "Fort Defiance, Arizona",
#   "latitude": "35.74446",
#   "longitude": "-109.076483",
#   "source": "Denver Public Library Special Collections",
#   "identifier": "ZZR710033458",
#   "type": "Image;StillImage",
#   "format": "image/jpeg",
#   "language": "eng",
#   "rights": "In Copyright - Non-commercial Use Permitted; Credit as \"Denver Public Library Special Collections\" unless otherwise noted.",
#   "reference_url": "https://lis-info671-fall2023.github.io/Group4-arizona-postcard/item.html?id=coll019"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://lis-info671-fall2023.github.io/Group4-arizona-postcard/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "adobe building": 1,
#         "architecture": 1,
#         "birds": 1,
#         "brick buildings": 2,
#         "cabins": 1,
#         "canyon wren": 1,
#         "canyons": 2,
#         "catherpes mexicanus": 1,
#         "chase creek": 1,
#         "churches": 5,
#         "clifton,arizona": 1,
#         "colorado river": 3,
#         "coronado trail": 6,
#         "corrals": 1,
#         "coyote": 1,
#         "defiance plateau": 1,
#         "father kino": 3,
#         "fishing": 2,
#         "forests": 1,
#         "fort defiance, arizona": 5,
#         "fortification": 1,
#         "grand canyon": 5,
#         "hannagan meadow": 1,
#         "hatch river expedition": 1,
#         "havasu canyon": 1,
#         "hiking trails": 1,
#         "historical markers": 1,
#         "juan bautista llorenz": 1,
#         "juan bautista velderrain": 1,
#         "lakes": 1,
#         "madonna of the trail monument": 1,
#         "mammals": 1,
#         "maps": 1,
#         "meadows": 1,
#         "mission san xavier del bac": 5,
#         "missions": 5,
#         "monuments": 1,
#         "national old trails road": 1,
#         "native american": 1,
#         "native americans": 1,
#         "nature sounds": 2,
#         "navajo nation": 3,
#         "postcards": 1,
#         "spanish exploration": 1,
#         "springerville, arizona": 2,
#         "streams": 1,
#         "swimming": 1,
#         "switchbacks": 1,
#         "tohono o'odham": 2,
#         "tucson, arizona": 2,
#         "tucson,arizona": 2,
#         "white mountains": 1,
#         "window rock": 1,
#         "wood building": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {
#         "department of transportation. federal highway administration. office of planning, environment, and realty. office of natural and human environment. national scenic byways program.": 6,
#         "national park service": 2,
#         "o'sullivan, timothy h., 1840-1882": 1,
#         "rose, noah h.": 1,
#         "thresher, g.p. (george p.)": 1,
#         "unknown": 9,
#         "wegener, bruce h.": 1
#       }
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 19,
#         "video/.mp4": 2
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - subject: grand canyon
# - subject: churches
# - creator: department of transportation. federal highway administration. office of planning, environment, and realty. office of natural and human environment. national scenic byways program.
# - format: image/jpeg

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is format: image/jpeg it is used 19 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title  \
# 0   Grand Canyon National Park - National Park Ser...
# 1                     Grand Canyon Nationa Park - Map
# 2   Grand Canyon Nationa Park - National Park Serv...
# 3               Grand Canyon National Park - Postcard
# 4          Grand Canyon National Park - Havasu Canyon
# 5                 San Xavier del Bac Mission - Facade
# 6               San Xavier del Bac Mission - Interior
# 7           San Xavier del Bac Mission - General View
# 8              San Xavier del Bac Mission - Rear View
# 9         San Xavier del Bac Mission - Southeast View
# 10  Coronado Trail Scenic Byway - Coronado Trail H...
# 11          Coronado Trail Scenic Byway - Summer Lake
# 12  Coronado Trail Scenic Byway - Switchbacks abov...
# 13  Coronado Trail Scenic Byway - Rustic Meadow Cabin
# 11        7717815                Image;StillImage  image/jpeg      eng
# 12        7717817                Image;StillImage  image/jpeg      eng
# 13        7717814                Image;StillImage  image/jpeg      eng
# 14        7717801                Image;StillImage  image/jpeg      eng
# 15        7717808                Image;StillImage  image/jpeg      eng
# 16   ZZR710033455                Image;StillImage  image/jpeg      eng
# 17   ZZR710033456                Image;StillImage  image/jpeg      eng
# 18   ZZR710033458                Image;StillImage  image/jpeg      eng
# 19   ZZR711001943                Image;StillImage  image/jpeg      eng
# 20   ZZR710033460                Image;StillImage  image/jpeg      eng
#
#                                                rights  \
# 0   Attribution-NonCommercial-NoDerivs 3.0 United ...
# 1   The Board of Regents of the University of Wisc...
# 2   Attribution-NonCommercial-NoDerivs 3.0 United ...
# 3                                       Public domain
# 4                             Copyright Not Evaluated
# 5            In Copyright - Educational Use Permitted
# 6            In Copyright - Educational Use Permitted
# 7   The University of Michigan Library provides ac...
# 8   The University of Michigan Library provides ac...
# 9   For information on use of Digital Library mate...
# 10                                      Public domain
# 11                                      Public domain
# 12                                      Public domain
# 13                                      Public domain
# 14                                      Public domain
# 15                                      Public domain
# 16  In Copyright - Non-commercial Use Permitted; C...
# 17  In Copyright - Non-commercial Use Permitted; C...
# 18  In Copyright - Non-commercial Use Permitted; C...
# 19  In Copyright - Non-commercial Use Permitted; C...
# 20  In Copyright - Non-commercial Use Permitted; C...
#
#                                       rightsstatement  \
# 0   https://creativecommons.org/licenses/by-nc-nd/...
# 1         https://www.wisconsin.edu/regents/policies/
# 2   https://creativecommons.org/licenses/by-nc-nd/...
# 3       http://rightsstatements.org/vocab/NoC-US/1.0/
# 4   https://rightsstatements.org/page/CNE/1.0/?lan...
# 5      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 6      http://rightsstatements.org/vocab/InC-EDU/1.0/
# 7                                                 NaN
# 8                                                 NaN
# 9   https://www.huntington.org/library-rights-perm...
# 10      http://rightsstatements.org/vocab/NoC-US/1.0/
# 11      http://rightsstatements.org/vocab/NoC-US/1.0/
# 12      http://rightsstatements.org/vocab/NoC-US/1.0/
# 13      http://rightsstatements.org/vocab/NoC-US/1.0/
# 14      http://rightsstatements.org/vocab/NoC-US/1.0/
# 15      http://rightsstatements.org/vocab/NoC-US/1.0/
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                         reference_url
# 0   https://lis-info671-fall2023.github.io/Group4-...
# 1   https://lis-info671-fall2023.github.io/Group4-...
# 2   https://lis-info671-fall2023.github.io/Group4-...
# 3   https://lis-info671-fall2023.github.io/Group4-...
# 4   https://lis-info671-fall2023.github.io/Group4-...
# 5   https://lis-info671-fall2023.github.io/Group4-...
# 6   https://lis-info671-fall2023.github.io/Group4-...
# 7   https://lis-info671-fall2023.github.io/Group4-...
# 8   https://lis-info671-fall2023.github.io/Group4-...
# 9   https://lis-info671-fall2023.github.io/Group4-...
# 10  https://lis-info671-fall2023.github.io/Group4-...
# 11  https://lis-info671-fall2023.github.io/Group4-...
# 12  https://lis-info671-fall2023.github.io/Group4-...
# 13  https://lis-info671-fall2023.github.io/Group4-...
# 14  https://lis-info671-fall2023.github.io/Group4-...
# 15  https://lis-info671-fall2023.github.io/Group4-...
# 16  https://lis-info671-fall2023.github.io/Group4-...
# 17  https://lis-info671-fall2023.github.io/Group4-...
# 18  https://lis-info671-fall2023.github.io/Group4-...
# 19  https://lis-info671-fall2023.github.io/Group4-...
# 20  https://lis-info671-fall2023.github.io/Group4-...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                 title  \
# 17  Fort Defiance - Native Americans (Navajo) buil...
# 16  Fort Defiance - Two, two story, brick building...
# 20     Fort Defiance - View of Fort Defiance, Arizona
# 9         San Xavier del Bac Mission - Southeast View
# 12  Coronado Trail Scenic Byway - Switchbacks abov...
# 10  Coronado Trail Scenic Byway - Coronado Trail H...
# 11          Coronado Trail Scenic Byway - Summer Lake
# 0   Grand Canyon National Park - National Park Ser...
# 3               Grand Canyon National Park - Postcard
# 4          Grand Canyon National Park - Havasu Canyon
#
#                                               creator        date  \
# 17                                            Unknown        1896
# 16                                            Unknown        1896
# 20                                      Rose, Noah H.        1900
# 9                          Thresher, G.P. (George P.)   1898-1910
# 12  Department of Transportation. Federal Highway ...        1991
# 10  Department of Transportation. Federal Highway ...        1991
# 11  Department of Transportation. Federal Highway ...        1991
# 0                               National Park Service  2006-08-06
# 3                                             Unknown  1905-03-14
# 4                                             Unknown   1950-1979
#
#                                           description  \
# 17  Native Americans (Navajo) build a wood and ado...
# 16  Two, two-story brick buildings and a fortifica...
# 20  View of Fort Defiance, Arizona. An orchard is ...
# 9   San Xavier del Bac Mission southeast view in T...
# 12  Switchbacks along the Coronado Trail Scenic By...
# 10  Historical marker along the Corondao Trail Sce...
# 11  Summer lake along the Coronado Trail Scenic By...
# 0   Audio tracks of animal sounds - Canyon Wren at...
# 3   Postcard of Grand Canyon National Park. Grand ...
# 4   Scene in Havasu Canyon, a major tributary of t...
#
#                                               subject  \
# 17  Fort Defiance, Arizona;Native Americans;Navajo...
# 16  Fort Defiance, Arizona;Brick Buildings;Fortifi...
# 20  Fort Defiance, Arizona;Defiance Plateau;Window...
# 9   Churches;Missions;Mission San Xavier del Bac;F...
# 12             Coronado Trail;Chase Creek;Switchbacks
# 10  Coronado Trail;Historical Markers;Hannagan Meadow
# 11              Coronado Trail;Lakes;Swimming;Fishing
# 0   Canyon Wren;Catherpes Mexicanus; Birds;Nature ...
# 3       Postcards;Canyons;Grand Canyon;Colorado River
# 4   Canyons;Havasu Canyon;Colorado River;Hatch Riv...
#
#                                              location     latitude  \
# 17                             Fort Defiance, Arizona     35.74446
# 16              Fort Defiance, Arizona; United States     35.74446
# 20                             Fort Defiance, Arizona     35.74446
# 9                                     Tucson, Arizona  32.10778171
# 12                      Chase Creek Overlook, Arizona     33.17222
# 10            Hannagan Meadow, Arizona; United States     33.63739
# 11                           White Mountains, Arizona      33.8805
# 0   Grand Canyon National Park; Arizona; United St...   36.3042826
# 3                 Grand Canyon National Park; Arizona   36.3042826
# 4   Havasu Canyon; Grand Canyon National Park; Ari...     36.30833
#
#        longitude                                             source  \
# 17   -109.076483          Denver Public Library Special Collections
# 16   -109.076483          Denver Public Library Special Collections
# 20   -109.076483          Denver Public Library Special Collections
# 9   -111.0085225  The Huntington Library, Art Museum, and Botani...
# 12     -109.3676      Records of the Federal Highway Administration
# 10    -109.32781      Records of the Federal Highway Administration
# 11    -109.41944      Records of the Federal Highway Administration
# 0   -112.7906529  NatureServe; J. Willard Marriott Library, Univ...
# 3   -112.7906529  Postcard Collection, The New York Public Libra...
# 4     -112.76135                                             Slides
#
#        identifier              type      format language  \
# 17   ZZR710033456  Image;StillImage  image/jpeg      eng
# 16   ZZR710033455  Image;StillImage  image/jpeg      eng
# 20   ZZR710033460  Image;StillImage  image/jpeg      eng
# 9          420288  Image;StillImage  image/jpeg      eng
# 12        7717817  Image;StillImage  image/jpeg      eng
# 10        7717811  Image;StillImage  image/jpeg      eng
# 11        7717815  Image;StillImage  image/jpeg      eng
# 0         1118642             Sound  video/.mp4      eng
# 3       MFY 95-29  Image;StillImage  image/jpeg      eng
# 4   p0781n1_12_25  Image;StillImage  image/jpeg      eng
#
#                                                rights  \
# 17  In Copyright - Non-commercial Use Permitted; C...
# 16  In Copyright - Non-commercial Use Permitted; C...
# 20  In Copyright - Non-commercial Use Permitted; C...
# 9   For information on use of Digital Library mate...
# 12                                      Public domain
# 10                                      Public domain
# 11                                      Public domain
# 0   Attribution-NonCommercial-NoDerivs 3.0 United ...
# 3                                       Public domain
# 4                             Copyright Not Evaluated
#
#                                       rightsstatement  \
# 17                                                NaN
# 16                                                NaN
# 20                                                NaN
# 9   https://www.huntington.org/library-rights-perm...
# 12      http://rightsstatements.org/vocab/NoC-US/1.0/
# 10      http://rightsstatements.org/vocab/NoC-US/1.0/
# 11      http://rightsstatements.org/vocab/NoC-US/1.0/
# 0   https://creativecommons.org/licenses/by-nc-nd/...
# 3       http://rightsstatements.org/vocab/NoC-US/1.0/
# 4   https://rightsstatements.org/page/CNE/1.0/?lan...
#
#                                         reference_url
# 17  https://lis-info671-fall2023.github.io/Group4-...
# 16  https://lis-info671-fall2023.github.io/Group4-...
# 20  https://lis-info671-fall2023.github.io/Group4-...
# 9   https://lis-info671-fall2023.github.io/Group4-...
# 12  https://lis-info671-fall2023.github.io/Group4-...
# 10  https://lis-info671-fall2023.github.io/Group4-...
# 11  https://lis-info671-fall2023.github.io/Group4-...
# 0   https://lis-info671-fall2023.github.io/Group4-...
# 3   https://lis-info671-fall2023.github.io/Group4-...
# 4   https://lis-info671-fall2023.github.io/Group4-...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
facet_frequency = {}
max_count = 0
most_frequent_facet_str = ""

for facet_info in total_facet_data['facets']:
    field_name = facet_info['field']
    terms_dict = facet_info['terms']
    for term, count in terms_dict.items():
        facet_string = f"{field_name}: {term}"
        facet_frequency[facet_string] = count
        if count > max_count:
            max_count = count
            most_frequent_facet_str = facet_string

print(f"The facet that comes up the most is {most_frequent_facet_str} with {max_count} times.")
# Out:
# The facet that comes up the most is format: image/jpeg with 19 times.

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
