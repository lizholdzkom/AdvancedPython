# %% [markdown]
# <a href="https://colab.research.google.com/github/lizholdzkom/AdvancedPython/blob/main/Holdzkom_Week_3_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Homework
#
# (Be sure to copy to drive first)
#
# For this homework we are going to apply some text analysis stuff to a collection of PDF file that I'll ask you to put together.

# %%
#Install / load our libraries and connect to Google Drive

# !pip install pypdf

#Colab has a special library just for working with files on google drive
from google.colab import drive


#This is a new library we'll use to extract text from PDFs
from pypdf import PdfReader


import textblob
import pandas as pd
import numpy as np
import glob

#Some extra libraries we'll need for text analysis
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('punkt_tab')

#Connect to Gdrive
drive.mount('/content/gdrive')

print("Libraries and Drive Ready!")
# Out:
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (6.7.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Libraries and Drive Ready!

# %% [markdown]
# **H1**
#
#
# Part of the work for this week is going to be finding a collection of 6 or so PDFs. These PDFS ideally should be on the same thing (journal articles on the same topic). Additionally these PDFs whould be Open Access, or the very least obtained lawfully * ***ahem*** *.
#
# Copy these 6 PDFs into the `LibraryJuicePython` folder on Google Drive. We'll be peforming some text analysis on these files.

# %%
#Run this cell to see the files in your directory
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  print(file)
# Out:
# /content/gdrive/MyDrive/LibraryJuicePython/SimoneEsteva_IDCC935_Fulltext.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/WeiseRauber_IJDC939_Final.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Lungley_IJDC_937_FullText.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Recker_IDCC_926_FullText.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf

# %% [markdown]
# # Exracting the text from the PDFs
#
# We'll use a Python Library to create a text file of the contents of the PDF file.

# %%
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  filename = file.split("/")[-1]
  print("Extracting text for... ",filename)

  text = ""
  #This bit is new!
  reader = PdfReader(file)
  for page in reader.pages:
    text += page.extract_text()

  #Output the string variable into a text file
  output_text_file = filename+".txt"
  with open(output_text_file, "w") as text_file:
    text_file.write(text)
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 21 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 45 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 51 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 96 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 179 0 (offset 0)
# Extracting text for...  SimoneEsteva_IDCC935_Fulltext.pdf
# Extracting text for...  awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf
# WARNING:pypdf._reader:Ignoring wrong pointing object 20 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 36 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 75 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 78 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 85 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 115 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 139 0 (offset 0)
# Extracting text for...  WeiseRauber_IJDC939_Final.pdf
# WARNING:pypdf._reader:Ignoring wrong pointing object 20 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 35 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 37 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 60 0 (offset 0)
# Extracting text for...  Lungley_IJDC_937_FullText.pdf
# WARNING:pypdf._reader:Ignoring wrong pointing object 20 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 24 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 40 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 51 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 87 0 (offset 0)
# Extracting text for...  Recker_IDCC_926_FullText.pdf
# Extracting text for...  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf

# %% [markdown]
# # Sentiment of our PDFs
#
# Let's just print our sentiment scores to the screen for now.

# %%
for file in glob.glob("*.txt"):
  print("Sentiment for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()
    blob = textblob.TextBlob(text)
    print(blob.sentiment)
    print("---")
# Out:
# Sentiment for  Recker_IDCC_926_FullText.pdf.txt
# Sentiment(polarity=0.06709931575710265, subjectivity=0.34040889969168653)
# ---
# Sentiment for  WeiseRauber_IJDC939_Final.pdf.txt
# Sentiment(polarity=0.12399517379489751, subjectivity=0.38851885453404766)
# ---
# Sentiment for  SimoneEsteva_IDCC935_Fulltext.pdf.txt
# Sentiment(polarity=0.05280988748094012, subjectivity=0.3552516781464149)
# ---
# Sentiment for  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf.txt
# Sentiment(polarity=0.1358700642791552, subjectivity=0.41288591944186354)
# ---
# Sentiment for  awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf.txt
# Sentiment(polarity=0.08267782188023479, subjectivity=0.37818833832238674)
# ---
# Sentiment for  Lungley_IJDC_937_FullText.pdf.txt
# Sentiment(polarity=0.10225067271438233, subjectivity=0.4415711304824208)
# ---

# %% [markdown]
# # Noun Phrases of our PDFs
#
# We'll just do the top 3 keywords of each file and display it to the screen

# %%
for file in glob.glob("*.txt"):
  print("Top 3 Phrases for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()

  blob = textblob.TextBlob(text)
  nphrases = dict()

  for np in blob.noun_phrases:
    if np in nphrases:
         nphrases[np] += 1
    else:
         nphrases[np] = 1

  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:3]:
      print(np, nphrases[np])

  print("---")
# Out:
# Top 3 Phrases for  Recker_IDCC_926_FullText.pdf.txt
# digital objects 17
# | conference 16
# preservation levels 16
# ---
# Top 3 Phrases for  WeiseRauber_IJDC939_Final.pdf.txt
# tres 45
# n = 31
# sensitive data 23
# ---
# Top 3 Phrases for  SimoneEsteva_IDCC935_Fulltext.pdf.txt
# ciwdn 20
# figure 12
# m. 12
# ---
# Top 3 Phrases for  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf.txt
# research data 17
# qdr 14
# colón 13
# ---
# Top 3 Phrases for  awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf.txt
# india 21
# dhas 19
# assam 11
# ---
# Top 3 Phrases for  Lungley_IJDC_937_FullText.pdf.txt
# ddi-cdi 16
# census 11
# | conference 10
# ---

# %% [markdown]
# # Dataframe of results
#
# Let's put our findings into a dataframe and save them to our drive. (We will use these PDFs again in our Week 4 work)

# %%
data_set = []

for file in glob.glob("*.txt"):

  pdf_detail = []

  with open(file,"r") as text_file:
    text = text_file.read()
  blob = textblob.TextBlob(text)

  print("working on ",file)
  pdf_detail.append(file)
  pdf_detail.append(blob.sentiment.polarity)
  pdf_detail.append(blob.sentiment.subjectivity)


  nphrases = dict()
  for np in blob.noun_phrases:
    if np in nphrases:
      nphrases[np] += 1
    else:
      nphrases[np] = 1

  #This is a weird way to find the top three keywords
  #This is an example of 'hacky' code

  #we loop through the first entry [0:1] in the sorted keyword list
  #giving us keyword one
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:1]:
      keyword_one = np
      pdf_detail.append(keyword_one)

  #we loop through the first entry [1:2] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[1:2]:
      keyword_two = np
      pdf_detail.append(keyword_two)

  #we loop through the first entry [2:3] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[2:3]:
      keyword_three = np
      pdf_detail.append(keyword_three)

  data_set.append(pdf_detail)
  print(pdf_detail)
  print("---")
# Out:
# working on  Recker_IDCC_926_FullText.pdf.txt
# ['Recker_IDCC_926_FullText.pdf.txt', 0.06709931575710265, 0.34040889969168653, 'digital objects', '| conference', 'preservation levels']
# ---
# working on  WeiseRauber_IJDC939_Final.pdf.txt
# ['WeiseRauber_IJDC939_Final.pdf.txt', 0.12399517379489751, 0.38851885453404766, 'tres', 'n =', 'sensitive data']
# ---
# working on  SimoneEsteva_IDCC935_Fulltext.pdf.txt
# ['SimoneEsteva_IDCC935_Fulltext.pdf.txt', 0.05280988748094012, 0.3552516781464149, 'ciwdn', 'figure', 'm.']
# ---
# working on  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf.txt
# ['awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf.txt', 0.1358700642791552, 0.41288591944186354, 'research data', 'qdr', 'colón']
# ---
# working on  awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf.txt
# ['awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf.txt', 0.08267782188023479, 0.37818833832238674, 'india', 'dhas', 'assam']
# ---
# working on  Lungley_IJDC_937_FullText.pdf.txt
# ['Lungley_IJDC_937_FullText.pdf.txt', 0.10225067271438233, 0.4415711304824208, 'ddi-cdi', 'census', '| conference']
# ---

# %%
#We now have a list of lists
#This sorta looks like JSON doesn't it?
data_set
# Out:
# [['Recker_IDCC_926_FullText.pdf.txt',
#   0.06709931575710265,
#   0.34040889969168653,
#   'digital objects',
#   '| conference',
#   'preservation levels'],
#  ['WeiseRauber_IJDC939_Final.pdf.txt',
#   0.12399517379489751,
#   0.38851885453404766,
#   'tres',
#   'n =',
#   'sensitive data'],
#  ['SimoneEsteva_IDCC935_Fulltext.pdf.txt',
#   0.05280988748094012,
#   0.3552516781464149,
#   'ciwdn',
#   'figure',
#   'm.'],
#  ['awhyte,+Journal+editor,+Karcher_etal_IJDC#837_FINAL.pdf.txt',
#   0.1358700642791552,
#   0.41288591944186354,
#   'research data',
#   'qdr',
#   'colón'],
#  ['awhyte,+Journal+editor,+Chakravarty-IJDC855-FINAL.pdf.txt',
#   0.08267782188023479,
#   0.37818833832238674,
#   'india',
#   'dhas',
#   'assam'],
#  ['Lungley_IJDC_937_FullText.pdf.txt',
#   0.10225067271438233,
#   0.4415711304824208,
#   'ddi-cdi',
#   'census',
#   '| conference']]

# %%
#Let's turn this list of lists into a pandas dataframe
pdf_dataframe = pd.DataFrame(data_set)
pdf_dataframe
# Out:
#                                                    0         1         2  \
# 0                   Recker_IDCC_926_FullText.pdf.txt  0.067099  0.340409
# 1                  WeiseRauber_IJDC939_Final.pdf.txt  0.123995  0.388519
# 2              SimoneEsteva_IDCC935_Fulltext.pdf.txt  0.052810  0.355252
# 3  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_...  0.135870  0.412886
# 4  awhyte,+Journal+editor,+Chakravarty-IJDC855-FI...  0.082678  0.378188
# 5                  Lungley_IJDC_937_FullText.pdf.txt  0.102251  0.441571
#
#                  3             4                    5
# 0  digital objects  | conference  preservation levels
# 1             tres           n =       sensitive data
# 2            ciwdn        figure                   m.
# 3    research data           qdr                colón
# 4            india          dhas                assam
# 5          ddi-cdi        census         | conference

# %% [markdown]
# **H2**
#
# Our dataframe needs better column names. Put the appropriate values into the list below on line 1 to update the column names.

# %%
column_names = ["Filename","Polarity","Subjectivity","Top Phrase 1","Top Phrase 2","Top Phrase 3"]
pdf_dataframe.columns = column_names
pdf_dataframe
# Out:
#                                             Filename  Polarity  Subjectivity  \
# 0                   Recker_IDCC_926_FullText.pdf.txt  0.067099      0.340409
# 1                  WeiseRauber_IJDC939_Final.pdf.txt  0.123995      0.388519
# 2              SimoneEsteva_IDCC935_Fulltext.pdf.txt  0.052810      0.355252
# 3  awhyte,+Journal+editor,+Karcher_etal_IJDC#837_...  0.135870      0.412886
# 4  awhyte,+Journal+editor,+Chakravarty-IJDC855-FI...  0.082678      0.378188
# 5                  Lungley_IJDC_937_FullText.pdf.txt  0.102251      0.441571
#
#       Top Phrase 1  Top Phrase 2         Top Phrase 3
# 0  digital objects  | conference  preservation levels
# 1             tres           n =       sensitive data
# 2            ciwdn        figure                   m.
# 3    research data           qdr                colón
# 4            india          dhas                assam
# 5          ddi-cdi        census         | conference

# %% [markdown]
# # Save our data
#
# We'll save our dataframe as a CSV file and put it in our usual folder.

# %%
pdf_dataframe.to_csv("adv_week3_homework.csv", index=False)
# !cp adv_week3_homework.csv /content/gdrive/MyDrive/LibraryJuicePython

# %% [markdown]
# **H3** Take a moment to reflect on what your data analysis says about your PDF files. Jot down some reflections in the cell below.

# %% [markdown]
# My analysis tells me that the noun phrases pulled from the text are a bit flawed. I'm unsure why the script grabbed the "|" before the word "conference". Otherwise, I think that even if the phrases pulled aren't giving us helpful information, they are the phrases that appear most often.
#
# I think that the polarity and subjectivity values probably make sense, since the content of the articles are mostly neutral (skewing positive), rather than noticeably positive or negative.

# %% [markdown]
# # All Done!
#
# Congrats you are finished with this week's work. Don't forget to click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work. Save this as a PDF and upload it to the Library Juice Academy site.
